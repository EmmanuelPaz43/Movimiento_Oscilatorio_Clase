# %% [markdown]
# <a href="https://colab.research.google.com/github/EmmanuelPaz43/Movimiento_Oscilatorio_Clase/blob/main/MAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np 
import math

def f1(A, P, t):
    return A*np.sin((2*np.pi/P)*t)

t1=np.arange(0, 10.00, 0.1)

A=float(input("Ingrese la amplitud del oscilador en metros: "))
T=float(input("Ingrese el periodo del oscilador en segundos: "))

plt.plot(t1, f1(A, T, t1))
plt.show()
# Out:
# Ingrese la amplitud del oscilador en metros: 5
# Ingrese el periodo del oscilador en segundos: 2
